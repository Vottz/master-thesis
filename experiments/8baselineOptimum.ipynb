# %%
from datetime import *
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

import gurobi as gb

import math
from statistics import mean 
from itertools import product

import sys 
import os
path = os.path.dirname(os.getcwd())
sys.path.append(path)
from lib import *

# %%
# Cloud Application Architecture data
data, vars_ms, userMax, ed, q = getConstantsFromBPMN('../flightBooking.json')


df = pd.read_csv(r'../data/projectcount_wikiDE_2014.csv')
clickData_hourly_2014 = df["de"]

# Read user data for each hour (Wikipedia clickData from 2015)
df = pd.read_csv(r'../data/projectcount_wikiDE_2015.csv')
clickData_hourly = df["De"].tolist()
clickData_hourly = clickData_hourly[24:] + clickData_hourly[0:24]

# Read carbon intensity data for each hour
df = pd.read_csv(r'../data/DE_2020.csv') # in gCO2eq per kWh
ci_2020 = df['carbon_intensity_avg']
df = pd.read_csv(r'../data/DE_2021.csv') # in gCO2eq per kWh
ci_2021 = df['carbon_intensity_avg']

cb = calcCarbonBudgetFrom_AVG_CE(clickData_hourly_2014,ci_2020)

numHours = 8760

# %%
# Premodifier (Aim: Efficiency)
vars_gb = [[]]


indices = []
for ms in data['components']:
    indices.append([0] * len(data['components'][ms]))

for i in indices:
    vars_gb *= len(i)

for i in range(len(vars_gb)):
    ed_combo = list(product(*ed))
    userMax_combo = list(product(*userMax))
    q_combo = list(product(*q))
    vars_gb[i].append([ed_combo[i], userMax_combo[i], q_combo[i]])


sf = [[] for h in range(numHours)]
for h in range(numHours):
    sf[h] = [[] for i in range(len(vars_gb))]
    for i in range(len(vars_gb)):
        sf[h][i] = [[] for ms in range(len(indices))]
        for ms in range(len(indices)):
            if ms == 0:
                sf[h][i][ms] = math.ceil(clickData_hourly[h] / vars_gb[0][i][1][ms])
            elif vars_gb[0][i][0][ms] == 0:
                sf[h][i][ms] = 0
            else:
                sf[h][i][ms] = math.ceil((sf[h][i][ms-1] * math.prod(vars_gb[0][i][2][0:ms])) / vars_gb[0][i][1][ms])
    
# Optimizer configuration, when all data for the whole year is known beforehand
opt_mod = gb.Model(name="globalView")
# Create optimization model
m = gb.Model('ca_microservice_global')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-07-19

# %%
# Variables
b = m.addVars([(h,i) for h in range(numHours) for i in range(len(vars_gb))],vtype=GRB.BINARY,name="b")
for h in range(numHours):
    m.addConstr(gb.quicksum(b[h,i] for i in range(len(vars_gb))) == 1, name="c-ms"+str(ms)+str(h))


m.addConstr(gb.quicksum(b[h,i]*sum(sf[h][i][ms]*vars_gb[0][i][0][ms] for ms in range(len(indices)))*ci_2021[h]
                         for h in range(numHours) for i in range(len(vars_gb))) <= cb)

m.update()
obj = gb.quicksum(b[h,i]*math.prod(vars_gb[0][i][2][0:len(indices)])*clickData_hourly[h] for h in range(numHours) for i in range(len(vars_gb))) 
m.setObjective(obj, GRB.MAXIMIZE)

m.tune()
m.optimize()
# Out:
# Solving model using baseline parameter set with TimeLimit=3600s
#
# Testing candidate parameter set 1...
#
# 	Default parameters
#
# Solving with random seed #1 ...
# Optimize a model with 8761 rows, 315360 columns and 630648 nonzeros
# Model fingerprint: 0x3868a2f5
# Variable types: 0 continuous, 315360 integer (315360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+07]
#   Objective range  [7e+03, 6e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.779820e+09
# Presolve removed 2 rows and 262811 columns
# Presolve time: 0.56s
# Presolved: 8759 rows, 52549 columns, 105098 nonzeros
# Variable types: 0 continuous, 52549 integer (52549 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.980735e+09, 160 iterations, 0.09 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.9807e+09    0    2 3.7798e+09 6.9807e+09  84.7%     -    0s
# H    0     0                    6.980733e+09 6.9807e+09  0.00%     -    0s
#
# Explored 1 nodes (160 simplex iterations) in 0.93 seconds (0.78 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6.98073e+09 3.77982e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.980732853391e+09, best bound 6.980735252803e+09, gap 0.0000%
#
# -------------------------------------------------------------------------------
#
# Solving with random seed #2 ...
# Optimize a model with 8761 rows, 315360 columns and 630648 nonzeros
# Model fingerprint: 0x3868a2f5
# Variable types: 0 continuous, 315360 integer (315360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+07]
#   Objective range  [7e+03, 6e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.764567e+09
# Presolve removed 2 rows and 262811 columns
# Presolve time: 0.54s
# Presolved: 8759 rows, 52549 columns, 105098 nonzeros
# Variable types: 0 continuous, 52549 integer (52549 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.980735e+09, 160 iterations, 0.07 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.9807e+09    0    2 3.7646e+09 6.9807e+09  85.4%     -    0s
# H    0     0                    6.980733e+09 6.9807e+09  0.00%     -    0s
#
# Explored 1 nodes (160 simplex iterations) in 0.87 seconds (0.79 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6.98073e+09 3.76457e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.980732853391e+09, best bound 6.980735252803e+09, gap 0.0000%
#
# -------------------------------------------------------------------------------
#
# Solving with random seed #3 ...
# Optimize a model with 8761 rows, 315360 columns and 630648 nonzeros
# Model fingerprint: 0x3868a2f5
# Variable types: 0 continuous, 315360 integer (315360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+07]
#   Objective range  [7e+03, 6e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.794475e+09
# Presolve removed 2 rows and 262811 columns
# Presolve time: 0.54s
# Presolved: 8759 rows, 52549 columns, 105098 nonzeros
# Variable types: 0 continuous, 52549 integer (52549 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.980735e+09, 160 iterations, 0.06 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.9807e+09    0    2 3.7945e+09 6.9807e+09  84.0%     -    0s
# H    0     0                    6.980733e+09 6.9807e+09  0.00%     -    0s
#
# Explored 1 nodes (160 simplex iterations) in 0.87 seconds (0.79 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6.98073e+09 3.79447e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.980732853391e+09, best bound 6.980735252803e+09, gap 0.0000%
#
# Setting total tuning time limit to 27s
# (set the TuneTimeLimit parameter to choose a different value)
#
# -------------------------------------------------------------------------------
# Begin tuning (baseline mean runtime 0.90s)...
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 2 ...
#
# 	Method 2
#
# Solving with random seed #1 ... runtime 1.04s
# Solving with random seed #2 ... runtime 1.01s
# Solving with random seed #3 ... runtime 1.01s+
#
# Total elapsed tuning time 6s (21s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 3 ...
#
# 	DegenMoves 2
#
# Solving with random seed #1 ... runtime 0.78s
# Solving with random seed #2 ... runtime 0.83s
# Solving with random seed #3 ... runtime 0.79s
#
# Improvement found:
#   baseline: mean runtime 0.90s
#   improved: mean runtime 0.80s
# Total elapsed tuning time 8s (19s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 4 ...
#
# 	DegenMoves 2
# 	Heuristics 0
#
# Solving with random seed #1 ... runtime 2.01s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.80s
# Total elapsed tuning time 10s (17s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 5 ...
#
# 	Method 0
# 	DegenMoves 2
#
# Solving with random seed #1 ... runtime 1.05s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.80s
# Total elapsed tuning time 11s (16s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 6 ...
#
# 	Method 0
#
# Solving with random seed #1 ... runtime 1.05s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.80s
# Total elapsed tuning time 12s (15s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 7 ...
#
# 	BranchDir -1
# 	DegenMoves 2
#
# Solving with random seed #1 ... runtime 0.79s
# Solving with random seed #2 ... runtime 0.77s
# Solving with random seed #3 ... runtime 0.79s
#
# Improvement found:
#   baseline: mean runtime 0.90s
#   improved: mean runtime 0.78s
# Total elapsed tuning time 15s (12s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 8 ...
#
# 	DegenMoves 2
# 	MIPFocus 1
#
# Solving with random seed #1 ... runtime 0.76s
# Solving with random seed #2 ... runtime 0.77s
# Solving with random seed #3 ... runtime 0.79s
#
# Improvement found:
#   baseline: mean runtime 0.90s
#   improved: mean runtime 0.77s
# Total elapsed tuning time 17s (10s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 9 ...
#
# 	DegenMoves 2
# 	LiftProjectCuts 1
#
# Solving with random seed #1 ... runtime 0.76s
# Solving with random seed #2 ... runtime 0.76s
# Solving with random seed #3 ... runtime 0.79s
#
# Improvement found:
#   baseline: mean runtime 0.90s
#   improved: mean runtime 0.77s
# Total elapsed tuning time 19s (8s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 10 ...
#
# 	DegenMoves 2
# 	MIPFocus 3
#
# Solving with random seed #1 ... runtime 2.19s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.77s
# Total elapsed tuning time 22s (6s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 11 ...
#
# 	Presolve 2
#
# Solving with random seed #1 ... runtime 1.03s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.77s
# Total elapsed tuning time 23s (4s remaining)
#
# -------------------------------------------------------------------------------
#
# Testing candidate parameter set 12 ...
#
# 	NormAdjust 1
# 	DegenMoves 2
#
# Solving with random seed #1 ... runtime 0.80s
# Solving with random seed #2 ... runtime 0.88s
# Solving with random seed #3 ... runtime 0.80s+
#
# Progress so far:
#   baseline: mean runtime 0.90s
#   best:     mean runtime 0.77s
# Total elapsed tuning time 25s (2s remaining)
#
# -------------------------------------------------------------------------------
#
# Tested 12 parameter sets in 25.05s
#
# Baseline parameter set: mean runtime 0.90s
#
# 	Default parameters
#
#  # Name              0        1        2      Avg      Max  Std Dev
#  0 ca_micros     0.94s    0.87s    0.88s    0.90s    0.94s     0.03
#
# Improved parameter set 1 (mean runtime 0.77s):
#
# 	DegenMoves 2
# 	LiftProjectCuts 1
#
#  # Name              0        1        2      Avg      Max  Std Dev
#  0 ca_micros     0.76s    0.76s    0.79s    0.77s    0.79s     0.02
#
# Improved parameter set 2 (mean runtime 0.80s):
#
# 	DegenMoves 2
#
#  # Name              0        1        2      Avg      Max  Std Dev
#  0 ca_micros     0.78s    0.83s    0.79s    0.80s    0.83s     0.02
#
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 8761 rows, 315360 columns and 630648 nonzeros
# Model fingerprint: 0x3868a2f5
# Variable types: 0 continuous, 315360 integer (315360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+07]
#   Objective range  [7e+03, 6e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+10]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.779820e+09
# Presolve removed 2 rows and 262811 columns
# Presolve time: 0.49s
# Presolved: 8759 rows, 52549 columns, 105098 nonzeros
# Variable types: 0 continuous, 52549 integer (52549 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.980735e+09, 160 iterations, 0.07 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.9807e+09    0    2 3.7798e+09 6.9807e+09  84.7%     -    0s
# H    0     0                    6.980733e+09 6.9807e+09  0.00%     -    0s
#
# Explored 1 nodes (160 simplex iterations) in 0.84 seconds (0.78 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6.98073e+09 3.77982e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.980732853391e+09, best bound 6.980735252803e+09, gap 0.0000%

# %% [markdown]
# # Save to csv

# %%
row = ["q","user-throughput","ed","eb","U","ce"]
f = open('../results/8_baselineOptimization_result.csv', 'w')
writer = csv.writer(f)
writer.writerow(row)
f.close()

weekday_frequency = weekdayfrequency(2021)
s_2021 = weekday_frequency.index(53)*24
carbonBudget = calcCarbonBudgetHourInWeekAVG(2020,clickData_hourly_2014,ci_2020)

f = open('../results/8_baselineOptimization_result.csv', 'a')
writer = csv.writer(f)
for (i, j),v in b.items():
    if v.X == 1.0:
        index = (i+s_2021)%168
        row = []
        energyDemand = sum([vars_gb[0][j][0][ms]*sf[i][j][ms] for ms in range(len(indices))])
        q = math.prod(vars_gb[0][j][2][0:len(indices)])
        u = math.prod(vars_gb[0][j][2][0:len(indices)])*clickData_hourly[i]
        carbonEmission = energyDemand * ci_2021[i]
        row.append(q)
        row.append(u)
        row.append(energyDemand)
        row.append(carbonBudget[index]/ci_2021[i])
        row.append(clickData_hourly[i])
        row.append(carbonEmission)
        writer.writerow(row)
f.close()
